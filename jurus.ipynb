# %% [markdown]
# <a href="https://colab.research.google.com/github/alexandrenoal/bibliotecaspython/blob/main/jurus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("meu nome é alexandre")
# Out:
# meu nome é alexandre

# %%
import pandas as pd

tabela = pd.read_excel("/content/drive/MyDrive/jurus2023.xlsx")
display(tabela)
# Out:
#    Juros 2023  LCI caixa  LCI Santander  Pouança caixa  Total mês
# 0     Janeiro       1570             22             33       1625
# 1   fevereiro       1297             19             35       1351
# 2       março       1674             24             32       1730
# 3       abril       1323             19             20       1362
# 4        maio       1632             23             18       1673
# 5       junho       1574             23             15       1612
# 6       julho       1590             23             26       1639
# 7      agosto       1707             23             10       1740
# 8    setembro       1476             21             11       1508
# 9     outubro       1525             22             14       1561
# 10   novembro       1416             19             18       1453
# 11   dezembro       1464             20             23       1507
